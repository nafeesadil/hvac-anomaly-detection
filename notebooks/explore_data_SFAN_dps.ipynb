# %% [markdown]
# # data Exploration
# ### data name : hochschule_wismar_gebaeude_001_lueftung_hoersaele_750.xlsx
#
# columne number= 11  SFAN_dps
#
# **starting date and time:** 23.may 2023 9:15 am
#
# **ending date and time:** 31.march. 2025 13:00 pm
#
# **data every 15 minutes**
#
# **information**
# *SFAN_dps ==0 when turned off and > 10 when turned on*
#
#  no negetive values
#
#
# **possible exploration**
#     • SFAN_DPS value change over the month, in 1 year eg, January= 60, feb 50 …

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Load Excel file
file_path = '../data/hochschule_wismar_gebaeude_001_lueftung_hoersaele_750.xlsx'
df = pd.read_excel(file_path)

# %%
df.head()
# Out:
#              datetime    EFAN_dps   EFAN_dpw      EHA_t      ETA_co  \
# 0 2023-05-23 09:15:00  256.942222  67.758000  21.777146  549.293333
# 1 2023-05-23 09:30:00  256.942222  65.468462  21.777146  549.293333
# 2 2023-05-23 09:45:00  256.710411  64.992852  21.777146  549.293333
# 3 2023-05-23 10:00:00  253.417115  66.077321  21.777146  549.293333
# 4 2023-05-23 10:15:00  256.764118  65.666078  21.777146  549.293333
#
#       ETA_rh      ETA_t     ODA_rh      ODA_t    PHEA_rh  ...  hum_load  \
# 0  50.723151  20.115667  79.308039  15.100000  64.574167  ...  5.722564
# 1  50.723151  20.115667  79.308039  15.100000  64.574167  ...  5.673126
# 2  50.723151  20.072412  79.308039  15.244078  64.574167  ...  5.290762
# 3  50.723151  20.004608  78.000000  15.209578  64.574167  ...  4.700040
# 4  50.723151  19.869961  77.920784  14.932206  64.574167  ...  3.365220
#
#    h_energy_actual  aux_energy  f_aux  fan_energy_actual h_energy_final  \
# 0         0.000000           0      0           1.144230              0
# 1        10.956503           0      0           1.126240              0
# 2        10.837688           0      0           1.123078              0
# 3        11.089365           0      0           1.116894              0
# 4        11.533710           0      0           1.128818              0
#
#    e_energy_final  energy_costs_total  operational  check_cool
# 0        0.000000            0.000000         True        True
# 1        0.730046            0.292019         True        True
# 2        0.728677            0.291471         True        True
# 3        0.732039            0.292816         True        True
# 4        0.732845            0.293138         True        True
#
# [5 rows x 64 columns]

# %%
df.tail()
# Out:
#                  datetime    EFAN_dps   EFAN_dpw      EHA_t      ETA_co  \
# 64139 2025-03-21 12:00:00  228.435933  54.552536  17.131770  530.464419
# 64140 2025-03-21 12:15:00  228.090362  55.164060  17.525086  526.051398
# 64141 2025-03-21 12:30:00  227.066846  54.530148  17.740075  525.472921
# 64142 2025-03-21 12:45:00  226.492837  53.971708  17.846202  520.716952
# 64143 2025-03-21 13:00:00  224.266259  53.000000  17.999149  514.126896
#
#           ETA_rh      ETA_t     ODA_rh      ODA_t    PHEA_rh  ...  hum_load  \
# 64139  29.890853  22.242171  34.634347  18.444506  18.521091  ...  5.310221
# 64140  28.552036  22.345254  32.137247  18.806078  17.150655  ...  6.938865
# 64141  28.000000  22.410924  33.038076  18.783987  17.849306  ...  4.504736
# 64142  27.880272  22.511482  32.436063  18.989990  17.498355  ...  5.639284
# 64143  27.021149  22.597885  31.000000  19.200000  17.000000  ...  6.264588
#
#        h_energy_actual  aux_energy  f_aux  fan_energy_actual h_energy_final  \
# 64139         4.896274           0      0           1.170534              0
# 64140         4.841950           0      0           1.175235              0
# 64141         4.831465           0      0           1.175440              0
# 64142         4.851591           0      0           1.163119              0
# 64143         4.676912           0      0           1.161337              0
#
#        e_energy_final  energy_costs_total  operational  check_cool
# 64139        0.643868            0.257547         True        True
# 64140        0.646788            0.258715         True        True
# 64141        0.644706            0.257882         True        True
# 64142        0.639942            0.255977         True        True
# 64143        0.637458            0.254983         True        True
#
# [5 rows x 64 columns]

# %%
# df.set_index('datetime')['SFAN_dps'].plot()
res = df.columns
print(res)
# Out:
# Index(['datetime', 'EFAN_dps', 'EFAN_dpw', 'EHA_t', 'ETA_co', 'ETA_rh',
#        'ETA_t', 'ODA_rh', 'ODA_t', 'PHEA_rh', 'PHEA_t', 'SFAN_dps', 'SFAN_dpw',
#        'SUP_rh', 'SUP_t', 'datetime.1', 'hours', 'SUP_x', 'SUP_h', 'ODA_x',
#        'ODA_h', 'ETA_x', 'ETA_h', 'SFAN_v', 'EFAN_v', 'PREC_t', 'PREC_x',
#        'PREC_rh', 'SUP_co', 'SFAN_efficiency_Fan', 'SFAN_l', 'SFAN_l%',
#        'SFAN_efficiency_Motor', 'SFAN_efficiencyAuxillary',
#        'SFAN_efficiencyOverall', 'EFAN_efficiency_Fan', 'EFAN_l', 'EFAN_l%',
#        'EFAN_efficiency_Motor', 'EFAN_efficiencyAuxillary',
#        'EFAN_efficiencyOverall', 'dt_fan', 'PREC_h', 'heatEnergy', 'rec_heat',
#        'rec_share', 'coolingEnergy', 'reheat', 'rec_cool', 'steam',
#        'rec_steam', 'rec_eff', 'heat_load', 'cool_load', 'hum_load',
#        'h_energy_actual', 'aux_energy', 'f_aux', 'fan_energy_actual',
#        'h_energy_final', 'e_energy_final', 'energy_costs_total', 'operational',
#        'check_cool'],
#       dtype='object')

# %%
print(df['datetime'].min())
print(df['datetime'].max())
# Out:
# 2023-05-23 09:15:00
# 2025-03-21 13:00:00

# %% [markdown]
# Below is the calculation of the percentage of the time the system was on per day. WEEKLY

# %%
start_date = '2023-06-01'
end_date = '2023-06-07'
# Create fan status column
df['fan_on'] = df['SFAN_dps'] > 0

# Filter first month and create a safe copy
df = df[(df['datetime'] >= start_date) & (df['datetime'] < end_date)].copy()

# Now this won't raise a warning
df['date'] = df['datetime'].dt.date

# Compute daily ON ratio
daily_on_ratio = df.groupby('date')['fan_on'].mean() * 100


# Generate full date range index
all_dates = pd.date_range(start=start_date, end=end_date, freq='D').date

# Reindex to include all days, even missing ones (NaN)
daily_on_ratio = daily_on_ratio.reindex(all_dates)

# Plot
daily_on_ratio.plot(title='Fan ON Ratio per Day (%)', figsize=(12, 5), marker='o')
plt.ylabel("On Ratio (%)")
plt.xlabel("Date")
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %%
negative_values = df[df['SFAN_dps'] < 0]
print(negative_values[['datetime', 'SFAN_dps']])
# Out:
# Empty DataFrame
# Columns: [datetime, SFAN_dps]
# Index: []

# %%
#HOURLY ON WEEkday (ffriday 2023) THE PERCENTAGE OF TIME THE FAN WAS ON

import pandas as pd
import matplotlib.pyplot as plt

# Filter data for the specific date
day = '2023-06-2'
start = pd.to_datetime(day)
end = start + pd.Timedelta(days=1)

# Create a copy of the data for that day
day_df = df[(df['datetime'] >= start) & (df['datetime'] < end)].copy()

# Create fan_on column if not already present
day_df['fan_on'] = day_df['SFAN_dps'] > 0

# Extract the hour
day_df['hour'] = day_df['datetime'].dt.hour

# Group by hour and calculate how often the fan was ON
hourly_on_ratio = day_df.groupby('hour')['fan_on'].mean() * 100  # in %

# Plot
hourly_on_ratio.plot(kind='bar', title=f'Hourly Fan ON Ratio (%) on {day}', figsize=(10, 5))
plt.ylabel("Fan ON Ratio (%)")
plt.xlabel("Hour of Day")
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
#HOURLY ON WEEKend (SATURDAY) THE PERCENTAGE OF TIME THE FAN WAS ON

import pandas as pd
import matplotlib.pyplot as plt

# Filter data for the specific date
day = '2023-06-03'
start = pd.to_datetime(day)
end = start + pd.Timedelta(days=1)

# Create a copy of the data for that day
day_df = df[(df['datetime'] >= start) & (df['datetime'] < end)].copy()

# Create fan_on column if not already present
day_df['fan_on'] = day_df['SFAN_dps'] > 0

# Extract the hour
day_df['hour'] = day_df['datetime'].dt.hour

# Group by hour and calculate how often the fan was ON
hourly_on_ratio = day_df.groupby('hour')['fan_on'].mean() * 100  # in %

# Plot
hourly_on_ratio.plot(kind='bar', title=f'Hourly Fan ON Ratio (%) on {day}', figsize=(10, 5))
plt.ylabel("Fan ON Ratio (%)")
plt.xlabel("Hour of Day")
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
##HOURLY ON WEEkday (monday 2024 ) THE PERCENTAGE OF TIME THE FAN WAS ON
import pandas as pd
import matplotlib.pyplot as plt

# Load Excel file and parse the datetime column
file_path = '../data/hochschule_wismar_gebaeude_001_lueftung_hoersaele_750.xlsx'
df = pd.read_excel(file_path, parse_dates=[0])  # assumes datetime is first column

# Rename the first column if it doesn't already have the name 'datetime'
if df.columns[0] != 'datetime':
    df.rename(columns={df.columns[0]: 'datetime'}, inplace=True)

# Filter data for a specific Monday (e.g. 2024-06-03)
day = '2024-06-03'
start = pd.to_datetime(day)
end = start + pd.Timedelta(days=1)

# Filter and copy relevant data
day_df = df[(df['datetime'] >= start) & (df['datetime'] < end)].copy()

# Check if data exists
if day_df.empty:
    print(f"No data found for {day}")
else:
    # Create fan_on column: True when SFAN_dps > 0
    day_df['fan_on'] = day_df['SFAN_dps'] > 0

    # Extract hour from datetime
    day_df['hour'] = day_df['datetime'].dt.hour

    # Group by hour and calculate % of time fan was ON
    hourly_on_ratio = day_df.groupby('hour')['fan_on'].mean() * 100

    # Plot
    hourly_on_ratio.plot(kind='bar', title=f'Monday Hourly Fan ON Ratio (%) on {day}', figsize=(10, 5))
    plt.ylabel("Fan ON Ratio (%)")
    plt.xlabel("Hour of Day")
    plt.xticks(rotation=0)
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()

# %%
##HOURLY ON WEEkEND (Sunday 2024 ) THE PERCENTAGE OF TIME THE FAN WAS ON
import pandas as pd
import matplotlib.pyplot as plt

# Load Excel file and parse the datetime column
file_path = '../data/hochschule_wismar_gebaeude_001_lueftung_hoersaele_750.xlsx'
df = pd.read_excel(file_path, parse_dates=[0])  # assumes datetime is first column

# Rename the first column if it doesn't already have the name 'datetime'
if df.columns[0] != 'datetime':
    df.rename(columns={df.columns[0]: 'datetime'}, inplace=True)

# Filter data for a specific Monday (e.g. 2024-06-03)
day = '2024-06-02'
start = pd.to_datetime(day)
end = start + pd.Timedelta(days=1)

# Filter and copy relevant data
day_df = df[(df['datetime'] >= start) & (df['datetime'] < end)].copy()

# Check if data exists
if day_df.empty:
    print(f"No data found for {day}")
else:
    # Create fan_on column: True when SFAN_dps > 0
    day_df['fan_on'] = day_df['SFAN_dps'] > 0

    # Extract hour from datetime
    day_df['hour'] = day_df['datetime'].dt.hour

    # Group by hour and calculate % of time fan was ON
    hourly_on_ratio = day_df.groupby('hour')['fan_on'].mean() * 100

    # Plot
    hourly_on_ratio.plot(kind='bar', title=f'Sunday Hourly Fan ON Ratio (%) on {day}', figsize=(10, 5))
    plt.ylabel("Fan ON Ratio (%)")
    plt.xlabel("Hour of Day")
    plt.xticks(rotation=0)
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # checking daylight saving

# %%
## checking WEEKDAY working hours before day-light saving (february) 
import pandas as pd
import matplotlib.pyplot as plt

# Load Excel file and parse the datetime column
file_path = '../data/hochschule_wismar_gebaeude_001_lueftung_hoersaele_750.xlsx'
df = pd.read_excel(file_path, parse_dates=[0])  # assumes datetime is first column

# Rename the first column if it doesn't already have the name 'datetime'
if df.columns[0] != 'datetime':
    df.rename(columns={df.columns[0]: 'datetime'}, inplace=True)

# Filter data 
day = '2024-02-05'
start = pd.to_datetime(day)
end = start + pd.Timedelta(days=1)

# Filter and copy relevant data
day_df = df[(df['datetime'] >= start) & (df['datetime'] < end)].copy()

# Check if data exists
if day_df.empty:
    print(f"No data found for {day}")
else:
    # Create fan_on column: True when SFAN_dps > 0
    day_df['fan_on'] = day_df['SFAN_dps'] > 0

    # Extract hour from datetime
    day_df['hour'] = day_df['datetime'].dt.hour

    # Group by hour and calculate % of time fan was ON
    hourly_on_ratio = day_df.groupby('hour')['fan_on'].mean() * 100

    # Plot
    hourly_on_ratio.plot(kind='bar', title=f' Before daylight saving (monday)(%) on {day}', figsize=(10, 5))
    plt.ylabel("Fan ON Ratio (%)")
    plt.xlabel("Hour of Day")
    plt.xticks(rotation=0)
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()

# %%
## checking WEEKend working hours before day-light saving (february) 
import pandas as pd
import matplotlib.pyplot as plt

# Load Excel file and parse the datetime column
file_path = '../data/hochschule_wismar_gebaeude_001_lueftung_hoersaele_750.xlsx'
df = pd.read_excel(file_path, parse_dates=[0])  # assumes datetime is first column

# Rename the first column if it doesn't already have the name 'datetime'
if df.columns[0] != 'datetime':
    df.rename(columns={df.columns[0]: 'datetime'}, inplace=True)

# Filter data 
day = '2024-02-03'
start = pd.to_datetime(day)
end = start + pd.Timedelta(days=1)

# Filter and copy relevant data
day_df = df[(df['datetime'] >= start) & (df['datetime'] < end)].copy()

# Check if data exists
if day_df.empty:
    print(f"No data found for {day}")
else:
    # Create fan_on column: True when SFAN_dps > 0
    day_df['fan_on'] = day_df['SFAN_dps'] > 0

    # Extract hour from datetime
    day_df['hour'] = day_df['datetime'].dt.hour

    # Group by hour and calculate % of time fan was ON
    hourly_on_ratio = day_df.groupby('hour')['fan_on'].mean() * 100

    # Plot
    hourly_on_ratio.plot(kind='bar', title=f' before daylight saving (saturday) (%) on {day}', figsize=(10, 5))
    plt.ylabel("Fan ON Ratio (%)")
    plt.xlabel("Hour of Day")
    plt.xticks(rotation=0)
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()
